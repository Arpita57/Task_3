# %% [markdown]
# # GRIP@ The Spark Foundation

# %% [markdown]
# # Task 3: Perform 'Exploratory Data Analytics-Retail' on dataset 'Sample Superstore'

# %% [markdown]
# # By: Arpita Bajaj

# %%
#Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Extracting Dataset

# %%
data=pd.read_csv("SampleSuperstore.csv")

# %%
#Showing first5 and last 5 rows.

# %%
data.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164

# %%
data.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# 9991       0.2  19.3932
# 9992       0.0  13.3200
# 9993       0.0  72.9480

# %%
data.shape
# Out:
# (9994, 13)

# %%
data.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
data.iloc[0:3,0:2]
# Out:
#       Ship Mode    Segment
# 0  Second Class   Consumer
# 1  Second Class   Consumer
# 2  Second Class  Corporate

# %%
#Data Cleaning- Removing null values, removingduplicate values

# %%
#Checking null values

# %%
data.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
#Checking datatypes

# %%
data.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %%
#Dropping irrelevant columns
data=data.drop(['Ship Mode','Segment','Country','Region'],axis=1)
data.head()
# Out:
#               City       State  Postal Code         Category Sub-Category  \
# 0        Henderson    Kentucky        42420        Furniture    Bookcases
# 1        Henderson    Kentucky        42420        Furniture       Chairs
# 2      Los Angeles  California        90036  Office Supplies       Labels
# 3  Fort Lauderdale     Florida        33311        Furniture       Tables
# 4  Fort Lauderdale     Florida        33311  Office Supplies      Storage
#
#       Sales  Quantity  Discount    Profit
# 0  261.9600         2      0.00   41.9136
# 1  731.9400         3      0.00  219.5820
# 2   14.6200         2      0.00    6.8714
# 3  957.5775         5      0.45 -383.0310
# 4   22.3680         2      0.20    2.5164

# %%
#Renaming the column names

# %%
data=data.rename(columns={"Postal Code":"Code","Sub-Category":"Sub_Cat"})
data.head()
# Out:
#               City       State   Code         Category    Sub_Cat     Sales  \
# 0        Henderson    Kentucky  42420        Furniture  Bookcases  261.9600
# 1        Henderson    Kentucky  42420        Furniture     Chairs  731.9400
# 2      Los Angeles  California  90036  Office Supplies     Labels   14.6200
# 3  Fort Lauderdale     Florida  33311        Furniture     Tables  957.5775
# 4  Fort Lauderdale     Florida  33311  Office Supplies    Storage   22.3680
#
#    Quantity  Discount    Profit
# 0         2      0.00   41.9136
# 1         3      0.00  219.5820
# 2         2      0.00    6.8714
# 3         5      0.45 -383.0310
# 4         2      0.20    2.5164

# %%
#Total number of rows and columns
data.shape
# Out:
# (9994, 9)

# %%
#Rows containing duplicate data
duplicate_rows_data = data[data.duplicated()]
print("Number of duplicate rows:",duplicate_rows_data.shape)
# Out:
# Number of duplicate rows: (76, 9)

# %%
#Counting the number of rows before removing the data
data.count()
# Out:
# City        9994
# State       9994
# Code        9994
# Category    9994
# Sub_Cat     9994
# Sales       9994
# Quantity    9994
# Discount    9994
# Profit      9994
# dtype: int64

# %%
#Dropping duplicates
data=data.drop_duplicates()
data.head()
# Out:
#               City       State   Code         Category    Sub_Cat     Sales  \
# 0        Henderson    Kentucky  42420        Furniture  Bookcases  261.9600
# 1        Henderson    Kentucky  42420        Furniture     Chairs  731.9400
# 2      Los Angeles  California  90036  Office Supplies     Labels   14.6200
# 3  Fort Lauderdale     Florida  33311        Furniture     Tables  957.5775
# 4  Fort Lauderdale     Florida  33311  Office Supplies    Storage   22.3680
#
#    Quantity  Discount    Profit
# 0         2      0.00   41.9136
# 1         3      0.00  219.5820
# 2         2      0.00    6.8714
# 3         5      0.45 -383.0310
# 4         2      0.20    2.5164

# %%
data.count()
# Out:
# City        9918
# State       9918
# Code        9918
# Category    9918
# Sub_Cat     9918
# Sales       9918
# Quantity    9918
# Discount    9918
# Profit      9918
# dtype: int64

# %%
#In which city we have the most sales
data['City'].value_counts()
# Out:
# New York City      903
# Los Angeles        733
# Philadelphia       528
# San Francisco      500
# Seattle            418
#                   ...
# Glenview             1
# Missouri City        1
# Rochester Hills      1
# Palatine             1
# Manhattan            1
# Name: City, Length: 531, dtype: int64

# %%
#Inserting top 10 cities with maximum sales
data['City'].value_counts()[0:10]
# Out:
# New York City    903
# Los Angeles      733
# Philadelphia     528
# San Francisco    500
# Seattle          418
# Houston          371
# Chicago          311
# Columbus         220
# San Diego        170
# Springfield      162
# Name: City, dtype: int64

# %%
data['City'].value_counts()[0:10].keys()
# Out:
# Index(['New York City', 'Los Angeles', 'Philadelphia', 'San Francisco',
#        'Seattle', 'Houston', 'Chicago', 'Columbus', 'San Diego',
#        'Springfield'],
#       dtype='object')

# %% [markdown]
# ## Data Visualization

# %%
#Bar plot of top 5 cities Vs it's sales values

# %%
plt.figure(figsize=(8,5))
plt.bar(list(data['City'].value_counts()[0:5].keys()),list(data['City'].value_counts()[0:5]),color='g')
plt.show()

# %%
#Extracting rcords of the sales with only profit into the variables 'Only_profit'.

# %%
Only_profit=data[data['Profit']>=0]
Only_profit.head()
# Out:
#               City       State   Code         Category      Sub_Cat    Sales  \
# 0        Henderson    Kentucky  42420        Furniture    Bookcases  261.960
# 1        Henderson    Kentucky  42420        Furniture       Chairs  731.940
# 2      Los Angeles  California  90036  Office Supplies       Labels   14.620
# 4  Fort Lauderdale     Florida  33311  Office Supplies      Storage   22.368
# 5      Los Angeles  California  90032        Furniture  Furnishings   48.860
#
#    Quantity  Discount    Profit
# 0         2       0.0   41.9136
# 1         3       0.0  219.5820
# 2         2       0.0    6.8714
# 4         2       0.2    2.5164
# 5         7       0.0   14.1694

# %%
#Extracting records of the sales with only loss into the variables 'Only_loss'

# %%
Only_loss=data[data['Profit']<0]

# %%
Only_loss.head()
# Out:
#                City         State   Code         Category     Sub_Cat  \
# 3   Fort Lauderdale       Florida  33311        Furniture      Tables
# 14       Fort Worth         Texas  76106  Office Supplies  Appliances
# 15       Fort Worth         Texas  76106  Office Supplies     Binders
# 23     Philadelphia  Pennsylvania  19140        Furniture      Chairs
# 27     Philadelphia  Pennsylvania  19140        Furniture   Bookcases
#
#         Sales  Quantity  Discount     Profit
# 3    957.5775         5      0.45  -383.0310
# 14    68.8100         5      0.80  -123.8580
# 15     2.5440         3      0.80    -3.8160
# 23    71.3720         2      0.30    -1.0196
# 27  3083.4300         7      0.50 -1665.0522

# %%
#Histogram

# %%
#Distribution of sales using histogram

# %%
plt.figure(figsize=(8,8))
plt.hist(Only_profit['Sales'])
plt.title("Distribution of Sales(profit)")
plt.xlabel("Sales")
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.hist(Only_loss['Sales'])
plt.title("Distribution of Sales(loss)")
plt.xlabel("Sales")
plt.show()

# %%
Only_profit['Sub_Cat'].value_counts()
# Out:
# Paper          1326
# Binders         909
# Art             790
# Furnishings     788
# Phones          750
# Accessories     683
# Storage         681
# Appliances      399
# Chairs          380
# Labels          361
# Envelopes       252
# Fasteners       204
# Supplies        155
# Bookcases       119
# Tables          115
# Machines         71
# Copiers          68
# Name: Sub_Cat, dtype: int64

# %%
max(Only_profit['Profit'])
# Out:
# 8399.976

# %%
Only_loss['Sub_Cat'].value_counts()
# Out:
# Binders        612
# Chairs         234
# Tables         203
# Furnishings    165
# Storage        161
# Phones         136
# Bookcases      109
# Accessories     91
# Appliances      67
# Machines        44
# Supplies        33
# Fasteners       12
# Name: Sub_Cat, dtype: int64

# %%
#Bar Plot

# %%
#Making a barplotfor top 3 sub categories with most profits.

# %%
plt.figure(figsize=(8,8))
plt.bar(list(data['Sub_Cat'].value_counts()[0:3].keys()),list(data['Sub_Cat'].value_counts()[0:3]),color={"blue","yellow","green"})
plt.show()

# %%
plt.figure(figsize=(20,20))
data.groupby('Category')['Profit','Sales'].agg(['sum']).plot.bar()
plt.ylabel('Profit')
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_8392/864123187.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data.groupby('Category')['Profit','Sales'].agg(['sum']).plot.bar()

# %%
#Pie Chart

# %%
#Pie chart showing the percentage of each subcategory

# %%
plt.figure(figsize=(7,7))
plt.pie(list(data['Sub_Cat'].value_counts()),labels=list(data['Sub_Cat'].value_counts().keys()),autopct='%.1f%%')
plt.show()

# %%
#Box-Plot

# %%
#Detecting Outliers with visualization using a box plot

# %%
sns.boxplot(x=data['Profit'])
# Out:
# <AxesSubplot:xlabel='Profit'>

# %%
sns.boxplot(x=data['Sales'])
# Out:
# <AxesSubplot:xlabel='Sales'>

# %%
sns.boxplot(x=data['Discount'])
# Out:
# <AxesSubplot:xlabel='Discount'>

# %%
sns.boxplot(x=data['Quantity'])
# Out:
# <AxesSubplot:xlabel='Quantity'>

# %%
#Removing the Outliers

# %%
Q1=data.quantile(0.25)
Q3=data.quantile(0.75)
IQR=Q3-Q1
print(IQR)
# Out:
# Code        66781.000000
# Sales         193.262500
# Quantity        3.000000
# Discount        0.200000
# Profit         27.868575
# dtype: float64

# %%
#Heat Maps

# %%
#Finding relations between the variables using Heat Maps

# %%
plt.figure(figsize=(20,10))
c=data.corr()
sns.heatmap(c,cmap="BrBG",annot=True)
c
# Out:
#               Code     Sales  Quantity  Discount    Profit
# Code      1.000000 -0.023453  0.013812  0.060094 -0.029905
# Sales    -0.023453  1.000000  0.200421 -0.028907  0.479033
# Quantity  0.013812  0.200421  1.000000  0.007871  0.066081
# Discount  0.060094 -0.028907  0.007871  1.000000 -0.220014
# Profit   -0.029905  0.479033  0.066081 -0.220014  1.000000

# %%
#Sales Vs Profit of 10 states

# %%
top_states_s=data.groupby("State").Sales.sum().nlargest(n=10)
top_states_p=data.groupby("State").Profit.sum().nlargest(n=10)
plt.style.use('seaborn')
top_states_s.plot(kind='bar',figsize=(10,5),fontsize=14)
top_states_p.plot(kind='bar',figsize=(10,5),fontsize=14,color='red')
plt.xlabel('States',fontsize=15)
plt.xlabel('Total Sales',fontsize=15)
plt.title("Top 10 states Sales Vs Profit",fontsize=15)
plt.show()

# %%
#Scatter Plot

# %%
#TO find the correlation betwwen two variables Sales and Profit

# %%
fig, ax=plt.subplots(figsize=(10,6))
ax.scatter(data['Sales'],data['Profit'])
ax.set_xlabel('Sales')
ax.set_ylabel('Profit')
plt.show()

# %%
#Pairplot

# %%
#Pairplot of all the attributes of the dataset

# %%
sns.pairplot(data)
